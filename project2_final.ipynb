# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Ames,-Iowa---Real-Estate-Analysis" data-toc-modified-id="Ames,-Iowa---Real-Estate-Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Ames, Iowa - Real Estate Analysis</a></span></li><li><span><a href="#Load-the-Data" data-toc-modified-id="Load-the-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load the Data</a></span></li><li><span><a href="#Cleaning-the-data" data-toc-modified-id="Cleaning-the-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Cleaning the data</a></span><ul class="toc-item"><li><span><a href="#Remove-Null-Columns" data-toc-modified-id="Remove-Null-Columns-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Remove Null Columns</a></span></li><li><span><a href="#Filling-in-Null-values" data-toc-modified-id="Filling-in-Null-values-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Filling in Null values</a></span></li><li><span><a href="#Remove-Duplicated-Rows" data-toc-modified-id="Remove-Duplicated-Rows-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Remove Duplicated Rows</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis-e-Preparation" data-toc-modified-id="Exploratory-Data-Analysis-e-Preparation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploratory Data Analysis e Preparation</a></span><ul class="toc-item"><li><span><a href="#Filter-out-non-Normal-sales" data-toc-modified-id="Filter-out-non-Normal-sales-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Filter out non-Normal sales</a></span></li><li><span><a href="#Investigate-categorical-variables-to-identity-non-significant-columns" data-toc-modified-id="Investigate-categorical-variables-to-identity-non-significant-columns-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Investigate categorical variables to identity non significant columns</a></span></li><li><span><a href="#Investigate-numerical-variables-to-identity-non-significant-columns" data-toc-modified-id="Investigate-numerical-variables-to-identity-non-significant-columns-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Investigate numerical variables to identity non significant columns</a></span><ul class="toc-item"><li><span><a href="#Define-feature-importance-using-random-forest" data-toc-modified-id="Define-feature-importance-using-random-forest-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Define feature importance using random forest</a></span></li><li><span><a href="#Confirm-feature-importance-using-correlation-coeficient" data-toc-modified-id="Confirm-feature-importance-using-correlation-coeficient-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Confirm feature importance using correlation coeficient</a></span></li></ul></li><li><span><a href="#Outliers-treatment" data-toc-modified-id="Outliers-treatment-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Outliers treatment</a></span></li></ul></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Ordinal-Variables" data-toc-modified-id="Ordinal-Variables-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Ordinal Variables</a></span></li><li><span><a href="#Categorical-Variables" data-toc-modified-id="Categorical-Variables-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Categorical Variables</a></span></li><li><span><a href="#Importance-analysis-on-the-final-set-of-variances" data-toc-modified-id="Importance-analysis-on-the-final-set-of-variances-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Importance analysis on the final set of variances</a></span></li></ul></li><li><span><a href="#Model-to-predict-House-Price-based-on-other-features" data-toc-modified-id="Model-to-predict-House-Price-based-on-other-features-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model to predict House Price based on other features</a></span><ul class="toc-item"><li><span><a href="#Defining-Test-and-Train-datasets" data-toc-modified-id="Defining-Test-and-Train-datasets-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Defining Test and Train datasets</a></span></li><li><span><a href="#Instantiate-and-fit-the-models-for-comparison" data-toc-modified-id="Instantiate-and-fit-the-models-for-comparison-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Instantiate and fit the models for comparison</a></span></li><li><span><a href="#Evaluate-the-models" data-toc-modified-id="Evaluate-the-models-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Evaluate the models</a></span></li><li><span><a href="#Scaling-the-variables" data-toc-modified-id="Scaling-the-variables-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Scaling the variables</a></span></li><li><span><a href="#Log-Transform-the-target" data-toc-modified-id="Log-Transform-the-target-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Log Transform the target</a></span></li><li><span><a href="#Linear-Model-with-Polynomial-Features" data-toc-modified-id="Linear-Model-with-Polynomial-Features-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Linear Model with Polynomial Features</a></span></li></ul></li><li><span><a href="#Model-to-predict-Overall-Quality-of-a-house-based-on-other-features" data-toc-modified-id="Model-to-predict-Overall-Quality-of-a-house-based-on-other-features-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Model to predict Overall Quality of a house based on other features</a></span><ul class="toc-item"><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Decision Tree</a></span></li></ul></li><li><span><a href="#Model-to-predict-High-Price-of-a-house-based-on-other-features" data-toc-modified-id="Model-to-predict-High-Price-of-a-house-based-on-other-features-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Model to predict High Price of a house based on other features</a></span><ul class="toc-item"><li><span><a href="#Build-the-models" data-toc-modified-id="Build-the-models-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Build the models</a></span><ul class="toc-item"><li><span><a href="#Random-Forest-Results" data-toc-modified-id="Random-Forest-Results-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Random Forest Results</a></span></li></ul></li></ul></li><li><span><a href="#Final-Conclusion-and-Recommendations" data-toc-modified-id="Final-Conclusion-and-Recommendations-9"><span class="toc-item-num">9&nbsp;&nbsp;</span><strong>Final Conclusion and Recommendations</strong></a></span><ul class="toc-item"><li><span><a href="#What-is-the-best-neighborhood-to-invest-and-with-the-highest-potential-for-valuation-over-time?" data-toc-modified-id="What-is-the-best-neighborhood-to-invest-and-with-the-highest-potential-for-valuation-over-time?-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span><strong>What is the best neighborhood to invest and with the highest potential for valuation over time?</strong></a></span></li><li><span><a href="#Once-we-identify-the-best-neighborhood,-should-he-consider-buying-an-older-house-and-renovating-before-selling-to-maximize-his-profit?" data-toc-modified-id="Once-we-identify-the-best-neighborhood,-should-he-consider-buying-an-older-house-and-renovating-before-selling-to-maximize-his-profit?-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span><strong>Once we identify the best neighborhood, should he consider buying an older house and renovating before selling to maximize his profit?</strong></a></span></li><li><span><a href="#What-are-the-ideal-house-features-to-look-for-when-deciding-on-investment?" data-toc-modified-id="What-are-the-ideal-house-features-to-look-for-when-deciding-on-investment?-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span><strong>What are the ideal house features to look for when deciding on investment?</strong></a></span></li><li><span><a href="#What-is-the-best-model-to-predict-house-sales-price-considering-the-data-available?" data-toc-modified-id="What-is-the-best-model-to-predict-house-sales-price-considering-the-data-available?-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span><strong>What is the best model to predict house sales price considering the data available?</strong></a></span></li><li><span><a href="#Can-we-predict-the-quality-of-a-house,-using-the-same-set-of-features?" data-toc-modified-id="Can-we-predict-the-quality-of-a-house,-using-the-same-set-of-features?-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span><strong>Can we predict the quality of a house, using the same set of features?</strong></a></span></li></ul></li></ul></div>

# %% [markdown]
# # Ames, Iowa - Real Estate Analysis

# %% [markdown]
# <img src="https://nycdsa-blog-files.s3.us-east-2.amazonaws.com/2020/12/mark-carthon/capture.jpg-878603-T4VGMy1A-1024x476.jpg">

# %% [markdown]
# John is very happy with our models for his winery and his used car business. By applying ML to his business, he was able to maximize his profits and his business became one of the leaders in the wine and car segment in Europe. Now, with his pocket full of money, he decided to invest in the US real estate market.
# After researching some potential places in the US, he has come through the city of Ames, Iowa. Now he wants our help to decide where to invest his well deserved money.
#
# - What is the best neighborhood to invest? What is the neighborhood with the highest potential for valuation over time?
# - Once we identify the best neighborhood, should he consider buying an older house and renovating before selling to maximize his profit?
# - What are the ideal house features to look for when deciding on investment?
# - What is the best model to predict house sales price considering the data available?
# - Can we predict the quality of a house, using the same set of features?

# %% [markdown]
# Data fields
#
# - SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# - MSSubClass: The building class
# - MSZoning: The general zoning classification
# - LotFrontage: Linear feet of street connected to property
# - LotArea: Lot size in square feet
# - Street: Type of road access
# - Alley: Type of alley access
# - LotShape: General shape of property
# - LandContour: Flatness of the property
# - Utilities: Type of utilities available
# - LotConfig: Lot configuration
# - LandSlope: Slope of property
# - Neighborhood: Physical locations within Ames city limits
# - Condition1: Proximity to main road or railroad
# - Condition2: Proximity to main road or railroad (if a second is present)
# - BldgType: Type of dwelling
# - HouseStyle: Style of dwelling
# - OverallQual: Overall material and finish quality
# - OverallCond: Overall condition rating
# - YearBuilt: Original construction date
# - YearRemodAdd: Remodel date
# - RoofStyle: Type of roof
# - RoofMatl: Roof material
# - Exterior1st: Exterior covering on house
# - Exterior2nd: Exterior covering on house (if more than one material)
# - MasVnrType: Masonry veneer type
# - MasVnrArea: Masonry veneer area in square feet
# - ExterQual: Exterior material quality
# - ExterCond: Present condition of the material on the exterior
# - Foundation: Type of foundation
# - BsmtQual: Height of the basement
# - BsmtCond: General condition of the basement
# - BsmtExposure: Walkout or garden level basement walls
# - BsmtFinType1: Quality of basement finished area
# - BsmtFinSF1: Type 1 finished square feet
# - BsmtFinType2: Quality of second finished area (if present)
# - BsmtFinSF2: Type 2 finished square feet
# - BsmtUnfSF: Unfinished square feet of basement area
# - TotalBsmtSF: Total square feet of basement area
# - Heating: Type of heating
# - HeatingQC: Heating quality and condition
# - CentralAir: Central air conditioning
# - Electrical: Electrical system
# - 1stFlrSF: First Floor square feet
# - 2ndFlrSF: Second floor square feet
# - LowQualFinSF: Low quality finished square feet (all floors)
# - GrLivArea: Above grade (ground) living area square feet
# - BsmtFullBath: Basement full bathrooms
# - BsmtHalfBath: Basement half bathrooms
# - FullBath: Full bathrooms above grade
# - HalfBath: Half baths above grade
# - Bedroom: Number of bedrooms above basement level
# - Kitchen: Number of kitchens
# - KitchenQual: Kitchen quality
# - TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# - Functional: Home functionality rating
# - Fireplaces: Number of fireplaces
# - FireplaceQu: Fireplace quality
# - GarageType: Garage location
# - GarageYrBlt: Year garage was built
# - GarageFinish: Interior finish of the garage
# - GarageCars: Size of garage in car capacity
# - GarageArea: Size of garage in square feet
# - GarageQual: Garage quality
# - GarageCond: Garage condition
# - PavedDrive: Paved driveway
# - WoodDeckSF: Wood deck area in square feet
# - OpenPorchSF: Open porch area in square feet
# - EnclosedPorch: Enclosed porch area in square feet
# - 3SsnPorch: Three season porch area in square feet
# - ScreenPorch: Screen porch area in square feet
# - PoolArea: Pool area in square feet
# - PoolQC: Pool quality
# - Fence: Fence quality
# - MiscFeature: Miscellaneous feature not covered in other categories
# - MiscVal: $Value of miscellaneous feature
# - MoSold: Month Sold
# - YrSold: Year Sold
# - SaleType: Type of sale
# - SaleCondition: Condition of sale

# %% [markdown]
# # Load the Data

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
import sklearn
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVR
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
#load main data

#GUACYRA
df = pd.read_csv('../_dataset_/P2_dataset.csv')

#RAQUEL
#df = pd.read_csv('../dataset/P2. dataset.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# ## Remove Null Columns

# %%
#GUACYRA
import sys
sys.path.insert(0, '')
from my_functions_EDA import *
from fx_MLClassification import *
from fx_MLRegression import *

#RAQUEL
#import sys
#sys.path.insert(0, '/Users/kelbritto/Downloads/AllWomen/_FUNCTIONS_')

from my_functions_EDA import *
from fx_MLRegression import *
from fx_MLClassification import *

# %%
nullcol = percentage_nullValues(df)
nullcol[nullcol["Percentage_NaN"] > 30]
# Out:
#              Percentage_NaN
# PoolQC                 99.5
# MiscFeature            96.3
# Alley                  93.8
# Fence                  80.8
# FireplaceQu            47.3

# %%
df.drop(["Id","PoolQC", "MiscFeature", "Alley", "Fence", "FireplaceQu"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1460, 75)

# %% [markdown]
# ## Filling in Null values

# %%
nulls = df.isnull().sum().reset_index()
nulls[nulls[0] > 0]
# Out:
#            index    0
# 2    LotFrontage  259
# 23    MasVnrType    8
# 24    MasVnrArea    8
# 28      BsmtQual   37
# 29      BsmtCond   37
# 30  BsmtExposure   38
# 31  BsmtFinType1   37
# 33  BsmtFinType2   38
# 40    Electrical    1
# 55    GarageType   81
# 56   GarageYrBlt   81
# 57  GarageFinish   81
# 60    GarageQual   81
# 61    GarageCond   81

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# ## Remove Duplicated Rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis e Preparation

# %% [markdown]
# ## Filter out non-Normal sales

# %% [markdown]
# John wants to invest in the Ames real estate market, therefore, we assume he is only interested in the housed sold under "Normal" Condition, as potentially the other conditions follow entirely different pricing models than normal sales. In this case, we will narrow down our analysis to focus only on Normal sales, which are 1198 of 1460 sales.

# %%
df["SaleCondition"].value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
df = df[df["SaleCondition"] == "Normal"]
df.shape
# Out:
# (1198, 75)

# %% [markdown]
# ## Investigate categorical variables to identity non significant columns

# %% [markdown]
# The original dataset constains 38 categorical columns. To avoid building an over complex model, we dropped the variables with poor statistical significance from the data set to be used in the model.

# %%
obj_col = df.select_dtypes(include='object')
num_col = df.select_dtypes(include=['int', 'float'])

# %%
len(obj_col.columns)
# Out:
# 38

# %%
for col in obj_col.columns:
    print(df[col].value_counts(normalize=True)*100)
# Out:
# RL         79.716194
# RM         15.776294
# FV          3.255426
# RH          0.918197
# C (all)     0.333890
# Name: MSZoning, dtype: float64
# Pave    99.582638
# Grvl     0.417362
# Name: Street, dtype: float64
# Reg    63.272120
# IR1    33.222037
# IR2     2.921536
# IR3     0.584307
# Name: LotShape, dtype: float64
# Lvl    90.317195
# Bnk     4.090150
# HLS     2.921536
# Low     2.671119
# Name: LandContour, dtype: float64
# AllPub    100.0
# Name: Utilities, dtype: float64
# Inside     71.953255
# Corner     17.612688
# CulDSac     6.594324
# FR2         3.505843
# FR3         0.333890
# Name: LotConfig, dtype: float64
# Gtl    94.574290
# Mod     4.674457
# Sev     0.751252
# Name: LandSlope, dtype: float64
# NAmes      16.527546
# CollgCr    10.767947
# OldTown     7.846411
# Edwards     6.844741
# Sawyer      5.592654
# Gilbert     5.342237
# NWAmes      5.342237
# BrkSide     4.507513
# SawyerW     4.173623
# Somerst     4.090150
# NridgHt     3.756260
# ...

# %% [markdown]
# **Removing columns with poor distribution of values**

# %% [markdown]
# The first strategy for the categorical variables was to remove all columns with poor distribution of values. If one element of the column represents more than 80% of the total records, the entire variable was removed from the dataset.

# %%
def eliminate_col(df, num):
    colums_to_elim = []
    for col in df.columns:
        if pd.Series(df[col].value_counts(normalize=True)*100 > num).any():
            colums_to_elim.append(col)
    return colums_to_elim

# %%
col_to_elim = eliminate_col(obj_col, 80)

# %%
df.drop(col_to_elim, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1198 entries, 0 to 1459
# Data columns (total 55 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1198 non-null   int64
#  1   MSZoning       1198 non-null   object
#  2   LotFrontage    1198 non-null   float64
#  3   LotArea        1198 non-null   int64
#  4   LotShape       1198 non-null   object
#  5   LotConfig      1198 non-null   object
#  6   Neighborhood   1198 non-null   object
#  7   HouseStyle     1198 non-null   object
#  8   OverallQual    1198 non-null   int64
#  9   OverallCond    1198 non-null   int64
#  10  YearBuilt      1198 non-null   int64
#  11  YearRemodAdd   1198 non-null   int64
#  12  RoofStyle      1198 non-null   object
#  13  Exterior1st    1198 non-null   object
#  14  Exterior2nd    1198 non-null   object
#  15  MasVnrType     1198 non-null   object
#  16  MasVnrArea     1198 non-null   float64
# ...

# %% [markdown]
# ## Investigate numerical variables to identity non significant columns

# %%
len(num_col.columns)
# Out:
# 37

# %% [markdown]
# ### Define feature importance using random forest

# %%
# random forest for feature importance on a regression problem
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor

# define dataset
X = num_col.drop("SalePrice", axis=1)
y = df["SalePrice"]
#print(X.columns)
model = RandomForestRegressor()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
#for i,v in enumerate(importance):#	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()

# %%
import_dict = []
for i,v in enumerate(importance):
    import_dict.append([X.columns[i], v])

feat_imp = pd.DataFrame(import_dict, columns=["feature", "importance"]).sort_values(by="importance", ascending=False)
feat_imp.importance = 100.0 * (feat_imp.importance / feat_imp.importance.max())
px.bar(feat_imp, x="feature", y="importance")
# Out:
# <div>                            <div id="c9e9460c-c018-47f1-8d7e-4d120096992a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9e9460c-c018-47f1-8d7e-4d120096992a")) {                    Plotly.newPlot(                        "c9e9460c-c018-47f1-8d7e-4d120096992a",                        [{"alignmentgroup": "True", "hovertemplate": "feature=%{x}<br>importance=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["OverallQual", "GrLivArea", "GarageArea", "BsmtFinSF1", "TotalBsmtSF", "GarageCars", "1stFlrSF", "LotArea", "2ndFlrSF", "MasVnrArea", "YearBuilt", "YearRemodAdd", "GarageYrBlt", "OverallCond", "TotRmsAbvGr
# ...

# %%
threshhold = 2
nom_imp_var = list(feat_imp.feature[feat_imp.importance < threshhold])
df.drop(nom_imp_var, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1198 entries, 0 to 1459
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MSZoning      1198 non-null   object
#  1   LotArea       1198 non-null   int64
#  2   LotShape      1198 non-null   object
#  3   LotConfig     1198 non-null   object
#  4   Neighborhood  1198 non-null   object
#  5   HouseStyle    1198 non-null   object
#  6   OverallQual   1198 non-null   int64
#  7   YearBuilt     1198 non-null   int64
#  8   YearRemodAdd  1198 non-null   int64
#  9   RoofStyle     1198 non-null   object
#  10  Exterior1st   1198 non-null   object
#  11  Exterior2nd   1198 non-null   object
#  12  MasVnrType    1198 non-null   object
#  13  MasVnrArea    1198 non-null   float64
#  14  ExterQual     1198 non-null   object
#  15  Foundation    1198 non-null   object
#  16  BsmtQual      1198 non-null   object
#  17  BsmtExposure  1198 non-null   object
# ...

# %% [markdown]
# ### Confirm feature importance using correlation coeficient

# %%
plt.figure(figsize = (15, 15))
corr_matrix=df.corr()
    
#create a mask 
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = True
    
# Draw the heatmap with the mask
ax = sns.heatmap(corr_matrix, mask=mask, annot=True, linewidths=.75, cmap ="Blues")
plt.show()

# %%
corr_table = pd.DataFrame(df.corrwith(df["SalePrice"]), columns=["corr"]).reset_index()
col_low_corr = list(corr_table["index"][corr_table["corr"] < 0.6])
col_low_corr
# Out:
# ['LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  '2ndFlrSF']

# %%
df.drop(['LotArea', 'GarageArea', 'BsmtFinSF1', '2ndFlrSF', '1stFlrSF','MasVnrType'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1198 entries, 0 to 1459
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MSZoning      1198 non-null   object
#  1   LotShape      1198 non-null   object
#  2   LotConfig     1198 non-null   object
#  3   Neighborhood  1198 non-null   object
#  4   HouseStyle    1198 non-null   object
#  5   OverallQual   1198 non-null   int64
#  6   YearBuilt     1198 non-null   int64
#  7   YearRemodAdd  1198 non-null   int64
#  8   RoofStyle     1198 non-null   object
#  9   Exterior1st   1198 non-null   object
#  10  Exterior2nd   1198 non-null   object
#  11  MasVnrArea    1198 non-null   float64
#  12  ExterQual     1198 non-null   object
#  13  Foundation    1198 non-null   object
#  14  BsmtQual      1198 non-null   object
#  15  BsmtExposure  1198 non-null   object
#  16  BsmtFinType1  1198 non-null   object
#  17  TotalBsmtSF   1198 non-null   int64
# ...

# %% [markdown]
# ## Outliers treatment

# %%
df.describe().T
# Out:
#                count           mean           std      min        25%  \
# OverallQual   1198.0       6.006678      1.318193      1.0       5.00
# YearBuilt     1198.0    1969.030885     29.493948   1872.0    1952.00
# YearRemodAdd  1198.0    1983.702003     20.277577   1950.0    1965.25
# MasVnrArea    1198.0      96.227880    175.760562      0.0       0.00
# TotalBsmtSF   1198.0    1024.569282    401.579758      0.0     793.00
# GrLivArea     1198.0    1492.968280    496.749621    334.0    1110.25
# GarageCars    1198.0       1.724541      0.709818      0.0       1.00
# SalePrice     1198.0  175202.219533  69713.636280  39300.0  130000.00
#
#                    50%        75%       max
# OverallQual        6.0       7.00      10.0
# YearBuilt       1971.0    1997.75    2009.0
# YearRemodAdd    1992.0    2002.00    2010.0
# MasVnrArea         0.0     148.00    1600.0
# TotalBsmtSF      969.0    1240.00    3206.0
# GrLivArea       1456.0    1766.25    4316.0
# ...

# %%
num_col = df.select_dtypes(include=['int', 'float'])
metrics = num_col.columns
for metric in metrics:
    fig = px.scatter(df, x="SalePrice", y=metric, color='Neighborhood', size_max=60)
    fig.update_layout(width=1200,height=400)
    fig.show()
# Out:
# <div>                            <div id="644788b0-b944-4a7b-a1b6-ac1c0f05ae67" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("644788b0-b944-4a7b-a1b6-ac1c0f05ae67")) {                    Plotly.newPlot(                        "644788b0-b944-4a7b-a1b6-ac1c0f05ae67",                        [{"hovertemplate": "Neighborhood=CollgCr<br>SalePrice=%{x}<br>OverallQual=%{y}<extra></extra>", "legendgroup": "CollgCr", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "CollgCr", "showlegend": true, "type": "scattergl", "x": [208500, 223500, 230000, 179900, 145000, 130250, 196500, 124900, 219500, 226000, 123600, 204750, 214000, 198900, 230000, 231500, 260000, 204000, 122000, 192000, 127000, 149000, 156000, 161750, 210000, 128200,
# ...

# %% [markdown]
# **Sale Price Outliers Treatment**
#
# For sales price, we removed those houses priced 500k and over as they show to be real outliers and would potentially affect the quality of the model. There is no significant outliers located at the far bottom of the distribution.

# %%
OutLiersBox(df,"SalePrice")
# Out:
# <div>                            <div id="bfd2a6bf-cf90-4ff3-8658-952de2e580ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfd2a6bf-cf90-4ff3-8658-952de2e580ad")) {                    Plotly.newPlot(                        "bfd2a6bf-cf90-4ff3-8658-952de2e580ad",                        [{"boxpoints": "all", "jitter": 0.3, "line": {"color": "rgb(7,40,89)"}, "marker": {"color": "rgb(7,40,89)"}, "name": "All Points", "pointpos": -1.8, "type": "box", "y": [208500, 181500, 223500, 250000, 143000, 307000, 200000, 118000, 129500, 144000, 157000, 132000, 149000, 90000, 159000, 139400, 230000, 129900, 154000, 256300, 134800, 306000, 207500, 68500, 40000, 149350, 179900, 165500, 277500, 309000, 145000, 153000, 170000, 144000, 130250, 141000, 319900, 24970
# ...

# %%
df[df["SalePrice"] > 500000]
# Out:
#      MSZoning LotShape LotConfig Neighborhood HouseStyle  OverallQual  \
# 440        RL      Reg    Inside      NridgHt     1Story           10
# 691        RL      IR1    Corner      NoRidge     2Story           10
# 769        RL      IR2   CulDSac      StoneBr     2Story            8
# 1169       RL      IR1   CulDSac      NoRidge     2Story           10
#
#       YearBuilt  YearRemodAdd RoofStyle Exterior1st  ... BsmtExposure  \
# 440        2008          2008       Hip     VinylSd  ...           Gd
# 691        1994          1995     Gable     HdBoard  ...           Gd
# 769        2003          2003       Hip     CemntBd  ...           Gd
# 1169       1995          1996       Hip     HdBoard  ...           Gd
#
#       BsmtFinType1 TotalBsmtSF HeatingQC GrLivArea KitchenQual GarageType  \
# 440            GLQ        3094        Ex      2402          Ex     Attchd
# 691            GLQ        2444        Ex      4316          Ex     Attchd
# ...

# %%
df.drop(df[df["SalePrice"] > 500000].index, inplace=True)
df[df["SalePrice"] > 500000]
# Out:
# Empty DataFrame
# Columns: [MSZoning, LotShape, LotConfig, Neighborhood, HouseStyle, OverallQual, YearBuilt, YearRemodAdd, RoofStyle, Exterior1st, Exterior2nd, MasVnrArea, ExterQual, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, TotalBsmtSF, HeatingQC, GrLivArea, KitchenQual, GarageType, GarageFinish, GarageCars, SalePrice]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# **TotalBsmtSF Outlier Treatment**
#
# For the total square feet of basement area, there are outliers at the both end of the distribution curve. However, for the lowest values, we assume those residences don't have a basement and therefore, should not be consider an outlier. On the far top, we decided to remove all the houses with basements greater than 2500 square feet.

# %%
OutLiersBox(df,"TotalBsmtSF")
# Out:
# <div>                            <div id="e4c6ce81-6e3a-4c75-898d-f060276322fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4c6ce81-6e3a-4c75-898d-f060276322fa")) {                    Plotly.newPlot(                        "e4c6ce81-6e3a-4c75-898d-f060276322fa",                        [{"boxpoints": "all", "jitter": 0.3, "line": {"color": "rgb(7,40,89)"}, "marker": {"color": "rgb(7,40,89)"}, "name": "All Points", "pointpos": -1.8, "type": "box", "y": [856, 1262, 920, 1145, 796, 1686, 1107, 991, 1040, 912, 1253, 832, 1004, 0, 1114, 637, 1777, 1040, 1060, 1566, 900, 1704, 1484, 520, 649, 1228, 1234, 1398, 1561, 1117, 1097, 1297, 1350, 840, 938, 1150, 1752, 1656, 955, 794, 816, 816, 1842, 384, 1425, 860, 780, 530, 1370, 576, 1057, 1143, 1947, 1453
# ...

# %%
df[df["TotalBsmtSF"] > 2500]
# Out:
#      MSZoning LotShape LotConfig Neighborhood HouseStyle  OverallQual  \
# 332        RL      IR1    Inside      NridgHt     1Story            8
# 496        RL      IR1    Inside      NoRidge     1Story            8
# 1044       RL      Reg    Inside       NWAmes     1Story            8
# 1373       RL      Reg    Inside      NoRidge     1Story           10
#
#       YearBuilt  YearRemodAdd RoofStyle Exterior1st  ... BsmtExposure  \
# 332        2003          2004     Gable     VinylSd  ...           No
# 496        1992          1993       Hip     BrkFace  ...           No
# 1044       1981          1981       Hip     BrkFace  ...           No
# 1373       2001          2002       Hip     VinylSd  ...           Gd
#
#       BsmtFinType1 TotalBsmtSF HeatingQC GrLivArea KitchenQual GarageType  \
# 332            GLQ        3206        Ex      1629          Gd     Attchd
# 496            GLQ        3200        Ex      3228          Gd     Attchd
# ...

# %%
df.drop(df[df["TotalBsmtSF"] > 2500].index, inplace=True)
df[df["TotalBsmtSF"] > 2500]
# Out:
# Empty DataFrame
# Columns: [MSZoning, LotShape, LotConfig, Neighborhood, HouseStyle, OverallQual, YearBuilt, YearRemodAdd, RoofStyle, Exterior1st, Exterior2nd, MasVnrArea, ExterQual, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, TotalBsmtSF, HeatingQC, GrLivArea, KitchenQual, GarageType, GarageFinish, GarageCars, SalePrice]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# **GrLivArea Outlier Treatment**
#
# For the above grade (ground) living area square feet, there are significant outliers at the top end of the distribution curve. We established a cut of 3000 sq feet to remove the outliers for this variable. By dropping these records, we will remain with a few outliers that should not significantly impact the quality of the model.

# %%
OutLiersBox(df,"GrLivArea")
# Out:
# <div>                            <div id="2b47dede-6892-48b1-b9c2-464ce6d28fd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b47dede-6892-48b1-b9c2-464ce6d28fd9")) {                    Plotly.newPlot(                        "2b47dede-6892-48b1-b9c2-464ce6d28fd9",                        [{"boxpoints": "all", "jitter": 0.3, "line": {"color": "rgb(7,40,89)"}, "marker": {"color": "rgb(7,40,89)"}, "name": "All Points", "pointpos": -1.8, "type": "box", "y": [1710, 1262, 1786, 2198, 1362, 1694, 2090, 1077, 1040, 912, 1253, 854, 1004, 1296, 1114, 1108, 1795, 1060, 1060, 1600, 900, 1704, 1600, 520, 1317, 1228, 1234, 1700, 1561, 2452, 1097, 1297, 1328, 884, 938, 1150, 1752, 1656, 955, 1470, 1176, 816, 1842, 1360, 1425, 1720, 780, 1111, 1370, 1710, 2034, 2
# ...

# %%
df[df["GrLivArea"] > 3000]
# Out:
#      MSZoning LotShape LotConfig Neighborhood HouseStyle  OverallQual  \
# 118        RL      Reg    Corner      SawyerW     2Story            7
# 185        RM      IR2    Inside      OldTown     2.5Fin           10
# 304        RM      Reg    Inside      OldTown     2.5Fin            7
# 1031       RL      Reg    Corner        SWISU     2.5Fin            7
# 1173       RL      IR1    Inside      ClearCr     1.5Fin            5
# 1268       RL      IR1    Inside      Crawfor     1.5Fin            8
# 1353       RL      IR1   CulDSac      NoRidge     1.5Fin            8
#
#       YearBuilt  YearRemodAdd RoofStyle Exterior1st  ... BsmtExposure  \
# 118        1990          1990       Hip     Plywood  ...           Mn
# 185        1892          1993     Gable     Wd Sdng  ...           Mn
# 304        1880          2002     Gable     CemntBd  ...           No
# 1031       1920          1970     Gable     Wd Sdng  ...           No
# ...

# %%
df.drop(df[df["GrLivArea"] > 3000].index, inplace=True)
df[df["GrLivArea"] > 3000]
# Out:
# Empty DataFrame
# Columns: [MSZoning, LotShape, LotConfig, Neighborhood, HouseStyle, OverallQual, YearBuilt, YearRemodAdd, RoofStyle, Exterior1st, Exterior2nd, MasVnrArea, ExterQual, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, TotalBsmtSF, HeatingQC, GrLivArea, KitchenQual, GarageType, GarageFinish, GarageCars, SalePrice]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# **Other variables Outlier Treatment**
#
# For the remainder of the variables ("OverallQual","Year Built" and "GarageCars") we did not eliminate outliers as they are mostly ordinal variables.

# %%
df.describe().T
# Out:
#                count           mean           std      min       25%  \
# OverallQual   1183.0       5.978022      1.291462      1.0       5.0
# YearBuilt     1183.0    1969.031276     29.309277   1872.0    1952.0
# YearRemodAdd  1183.0    1983.559594     20.339620   1950.0    1965.0
# MasVnrArea    1183.0      92.745562    166.846293      0.0       0.0
# TotalBsmtSF   1183.0    1012.104818    378.032120      0.0     791.5
# GrLivArea     1183.0    1472.326289    459.481156    334.0    1102.5
# GarageCars    1183.0       1.713440      0.701615      0.0       1.0
# SalePrice     1183.0  172174.352494  62358.037817  39300.0  129900.0
#
#                    50%       75%       max
# OverallQual        6.0       7.0      10.0
# YearBuilt       1970.0    1997.5    2009.0
# YearRemodAdd    1992.0    2002.0    2010.0
# MasVnrArea         0.0     145.5    1600.0
# TotalBsmtSF      960.0    1230.0    2392.0
# GrLivArea       1442.0    1742.0    2978.0
# ...

# %% [markdown]
# # Feature Engineering

# %%
obj_col = df.select_dtypes(include='object')
obj_col.columns
# Out:
# Index(['MSZoning', 'LotShape', 'LotConfig', 'Neighborhood', 'HouseStyle',
#        'RoofStyle', 'Exterior1st', 'Exterior2nd', 'ExterQual', 'Foundation',
#        'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'HeatingQC', 'KitchenQual',
#        'GarageType', 'GarageFinish'],
#       dtype='object')

# %% [markdown]
# ---

# %%
for col in obj_col:
    print(df[col].value_counts())
# Out:
# RL         942
# RM         187
# FV          39
# RH          11
# C (all)      4
# Name: MSZoning, dtype: int64
# Reg    752
# IR1    391
# IR2     33
# IR3      7
# Name: LotShape, dtype: int64
# Inside     853
# Corner     208
# CulDSac     76
# FR2         42
# FR3          4
# Name: LotConfig, dtype: int64
# NAmes      198
# CollgCr    129
# OldTown     92
# Edwards     82
# Sawyer      67
# Gilbert     64
# NWAmes      63
# BrkSide     54
# Somerst     49
# SawyerW     49
# NridgHt     43
# Crawfor     42
# Mitchel     42
# NoRidge     32
# IDOTRR      29
# Timber      28
# ClearCr     23
# SWISU       21
# MeadowV     16
# StoneBr     15
# Blmngtn     12
# BrDale      12
# Veenker     11
# NPkVill      8
# Blueste      2
# Name: Neighborhood, dtype: int64
# 1Story    572
# 2Story    366
# 1.5Fin    132
# SLvl       56
# SFoyer     29
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      3
# Name: HouseStyle, dtype: int64
# Gable      934
# Hip        222
# Gambrel     10
# ...

# %% [markdown]
# ## Ordinal Variables

# %% [markdown]
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor

# %%
ord_var = ["ExterQual", "BsmtQual", "KitchenQual", "HeatingQC"]
ord_map = dict(zip(["Ex", "Gd", "Ta", "TA","Fa", "Po"],[0,1,2,2,3,4]))

# %%
df.replace(ord_map, inplace=True)
df
# Out:
#      MSZoning LotShape LotConfig Neighborhood HouseStyle  OverallQual  \
# 0          RL      Reg    Inside      CollgCr     2Story            7
# 1          RL      Reg       FR2      Veenker     1Story            6
# 2          RL      IR1    Inside      CollgCr     2Story            7
# 4          RL      IR1       FR2      NoRidge     2Story            8
# 5          RL      IR1    Inside      Mitchel     1.5Fin            5
# ...       ...      ...       ...          ...        ...          ...
# 1455       RL      Reg    Inside      Gilbert     2Story            6
# 1456       RL      Reg    Inside       NWAmes     1Story            6
# 1457       RL      Reg    Inside      Crawfor     2Story            7
# 1458       RL      Reg    Inside        NAmes     1Story            5
# 1459       RL      Reg    Inside      Edwards     1Story            5
#
#       YearBuilt  YearRemodAdd RoofStyle Exterior1st  ... BsmtExposure  \
# ...

# %% [markdown]
# ## Categorical Variables

# %%
def labeling_func(df, col):
    print("Value count before relabeling:\n","-"*20)
    print(df[col].value_counts())
    u_val_dict = dict(df[col].value_counts())
    col_map = dict(zip([*u_val_dict],range(len(u_val_dict))))
    df.replace(col_map, inplace=True)
    print("Value count after relabeling:\n","-"*20)
    print(df[col].value_counts())

# %%
cat_var = ['MSZoning','LotShape','LotConfig','BsmtExposure','Exterior1st','Exterior2nd','BsmtFinType1',
          'Foundation','GarageFinish','GarageType','HouseStyle','RoofStyle','MasVnrType','Neighborhood']
for col in cat_var:
    if col != "Neighborhood":
        labeling_func(df,col)
# Out:
# Value count before relabeling:
#  --------------------
# RL         942
# RM         187
# FV          39
# RH          11
# C (all)      4
# Name: MSZoning, dtype: int64
# Value count after relabeling:
#  --------------------
# 0    942
# 1    187
# 2     39
# 3     11
# 4      4
# Name: MSZoning, dtype: int64
# Value count before relabeling:
#  --------------------
# Reg    752
# IR1    391
# IR2     33
# IR3      7
# Name: LotShape, dtype: int64
# Value count after relabeling:
#  --------------------
# 0    752
# 1    391
# 2     33
# 3      7
# Name: LotShape, dtype: int64
# Value count before relabeling:
#  --------------------
# Inside     853
# Corner     208
# CulDSac     76
# FR2         42
# FR3          4
# Name: LotConfig, dtype: int64
# Value count after relabeling:
#  --------------------
# 0    853
# 1    208
# 2     76
# 3     42
# 4      4
# Name: LotConfig, dtype: int64
# Value count before relabeling:
#  --------------------
# No    799
# Av    161
# 1     101
# ...

# %% [markdown]
# ## Importance analysis on the final set of variances

# %% [markdown]
# The strategy to build the model was apply a Random Forest Regressor to get the features with the highest importance with the target Sale Price.
#
# Previously, it was also evaluated the strategy by applying a Linear Regression to get the features with the highest coefficients, but this method did not prove to yield good results.

# %%
df_model = df.iloc[:,:23]
df_model
# Out:
#       MSZoning  LotShape  LotConfig Neighborhood  HouseStyle  OverallQual  \
# 0            3         3          3      CollgCr           1            7
# 1            3         3          3      Veenker           0            3
# 2            3         2          3      CollgCr           1            7
# 4            3         2          3      NoRidge           1            8
# 5            3         2          3      Mitchel           2            7
# ...        ...       ...        ...          ...         ...          ...
# 1455         3         3          3      Gilbert           1            3
# 1456         3         3          3       NWAmes           0            3
# 1457         3         3          3      Crawfor           1            7
# 1458         3         3          3        NAmes           0            7
# 1459         3         3          3      Edwards           0            7
#
#       YearBuilt  YearRemodAdd  RoofStyle  Exterior1st  ...  Foundation  \
# ...

# %%
cat_col = ['MSZoning', 'LotShape', 'LotConfig', 'Neighborhood', 'HouseStyle',
       'RoofStyle', 'Exterior1st', 'Exterior2nd', 'ExterQual',
       'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'HeatingQC',
       'KitchenQual', 'GarageType', 'GarageFinish','SalePrice']

# %%
df[cat_col]
# Out:
#       MSZoning  LotShape  LotConfig Neighborhood  HouseStyle  RoofStyle  \
# 0            3         3          3      CollgCr           1          0
# 1            3         3          3      Veenker           0          0
# 2            3         2          3      CollgCr           1          0
# 4            3         2          3      NoRidge           1          0
# 5            3         2          3      Mitchel           2          0
# ...        ...       ...        ...          ...         ...        ...
# 1455         3         3          3      Gilbert           1          0
# 1456         3         3          3       NWAmes           0          0
# 1457         3         3          3      Crawfor           1          0
# 1458         3         3          3        NAmes           0          1
# 1459         3         3          3      Edwards           0          0
#
#       Exterior1st  Exterior2nd  ExterQual  Foundation  BsmtQual  BsmtExposure  \
# ...

# %%
# random forest for feature importance on a regression problem
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor

# define dataset
X = df.drop(["SalePrice", "Neighborhood"], axis=1)
y = df["SalePrice"]
#print(X.columns)
model = RandomForestRegressor()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
#for i,v in enumerate(importance):#	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()

# %%
import_dict = []
for i,v in enumerate(importance):
    import_dict.append([X.columns[i], v])

feat_imp = pd.DataFrame(import_dict, columns=["feature", "importance"]).sort_values(by="importance", ascending=False)
feat_imp.importance = 100.0 * (feat_imp.importance / feat_imp.importance.max())
px.bar(feat_imp, x="feature", y="importance")
# Out:
# <div>                            <div id="39360889-abd7-482c-972e-75cdfc8fbe09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39360889-abd7-482c-972e-75cdfc8fbe09")) {                    Plotly.newPlot(                        "39360889-abd7-482c-972e-75cdfc8fbe09",                        [{"alignmentgroup": "True", "hovertemplate": "feature=%{x}<br>importance=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["GrLivArea", "OverallQual", "TotalBsmtSF", "YearBuilt", "YearRemodAdd", "GarageFinish", "MasVnrArea", "GarageType", "GarageCars", "BsmtExposure", "LotShape", "BsmtFinType1", "RoofStyle", "Exterior2nd", "Bs
# ...

# %%
threshold = 2.5
nom_imp_var = list(feat_imp.feature[feat_imp.importance < threshold])
df.drop(nom_imp_var, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1183 entries, 0 to 1459
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Neighborhood  1183 non-null   object
#  1   OverallQual   1183 non-null   int64
#  2   YearBuilt     1183 non-null   int64
#  3   YearRemodAdd  1183 non-null   int64
#  4   MasVnrArea    1183 non-null   float64
#  5   TotalBsmtSF   1183 non-null   int64
#  6   GrLivArea     1183 non-null   int64
#  7   GarageFinish  1183 non-null   int64
#  8   SalePrice     1183 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 92.4+ KB

# %%
fig = px.scatter(df, x="SalePrice", y="GrLivArea", color=str("OverallQual"))
fig.update_layout(width=1000,height=400)
fig.show()
# Out:
# <div>                            <div id="f859d707-0d89-4373-a0b0-dffc16d39a1c" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f859d707-0d89-4373-a0b0-dffc16d39a1c")) {                    Plotly.newPlot(                        "f859d707-0d89-4373-a0b0-dffc16d39a1c",                        [{"hovertemplate": "SalePrice=%{x}<br>GrLivArea=%{y}<br>OverallQual=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [7, 3, 7, 8, 7, 8, 7, 7, 7, 7, 3, 7, 3, 3, 7, 7, 8, 7, 7, 8, 7, 8, 7, 3, 3, 7, 8, 7, 9, 8, 7, 7, 7, 7, 7, 7, 9, 8, 7, 3, 3, 7, 9, 7, 3, 7, 7, 7, 8, 7, 7, 8, 7, 7, 3, 7, 7, 3, 7, 7, 3, 3, 3, 7, 3, 7, 3, 3, 8, 7, 7, 8, 3, 3, 3, 7, 3, 3, 3, 7, 3, 3, 3, 3, 7, 7, 8, 3, 7, 3, 3, 7, 3, 3, 7, 3, 3, 3, 3, 3, 3, 3, 7, 3, 7, 3, 7, 8, 7
# ...

# %%
fig = px.scatter(df, x="SalePrice", y="YearBuilt", color=str("OverallQual"))
fig.update_layout(width=1000,height=400)
fig.show()
# Out:
# <div>                            <div id="77525dd2-949e-4799-a073-1de44bb99af4" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77525dd2-949e-4799-a073-1de44bb99af4")) {                    Plotly.newPlot(                        "77525dd2-949e-4799-a073-1de44bb99af4",                        [{"hovertemplate": "SalePrice=%{x}<br>YearBuilt=%{y}<br>OverallQual=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [7, 3, 7, 8, 7, 8, 7, 7, 7, 7, 3, 7, 3, 3, 7, 7, 8, 7, 7, 8, 7, 8, 7, 3, 3, 7, 8, 7, 9, 8, 7, 7, 7, 7, 7, 7, 9, 8, 7, 3, 3, 7, 9, 7, 3, 7, 7, 7, 8, 7, 7, 8, 7, 7, 3, 7, 7, 3, 7, 7, 3, 3, 3, 7, 3, 7, 3, 3, 8, 7, 7, 8, 3, 3, 3, 7, 3, 3, 3, 7, 3, 3, 3, 3, 7, 7, 8, 3, 7, 3, 3, 7, 3, 3, 7, 3, 3, 3, 3, 3, 3, 3, 7, 3, 7, 3, 7, 8, 7
# ...

# %% [markdown]
# # Model to predict House Price based on other features

# %% [markdown]
# ## Defining Test and Train datasets

# %%
X = df.drop(["SalePrice", "Neighborhood"], axis=1)
y = df["SalePrice"]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,
                                                    random_state=42)

# %%
print('Shape of the raw data (X): {}'.format (X.shape))
print('Shape of the TARGET variable (y): {}'.format (y.shape))

print('\nShape of the Train data (X_train): {}'.format (X_train.shape))
print('Shape of the Train data (y_train): {}'.format (y_train.shape))

print('\nShape of the Test data (X_test): {}'.format (X_test.shape))
print('Shape of the TARGET Test data (y_test): {}'.format (y_test.shape))
# Out:
# Shape of the raw data (X): (1183, 7)
# Shape of the TARGET variable (y): (1183,)
#
# Shape of the Train data (X_train): (828, 7)
# Shape of the Train data (y_train): (828,)
#
# Shape of the Test data (X_test): (355, 7)
# Shape of the TARGET Test data (y_test): (355,)

# %% [markdown]
# ## Instantiate and fit the models for comparison

# %%
def Reg_getBasedModel():
    basedModels = []
    basedModels.append(('LinearR'   , LinearRegression()))
    basedModels.append(('Ridge'   , Ridge()))
    basedModels.append(('Lasso'   , Lasso()))
    basedModels.append(('DT' , DecisionTreeRegressor()))
    #basedModels.append(('SVM-R'  , SVR()))
    basedModels.append(('RF'   , RandomForestRegressor()))
    #basedModels.append(('Polynomial'   , PolynomialFeatures(degree=2)))
    return basedModels

# %%
def Reg_basedModels(X_train, y_train,models):
    """
    BasedModels will return the evaluation metric 'r2 after performing
    a CV for each of the models
    input:
    X_train
    y_train
    models = array containing the different instantiated models
    
    output:
    names = names of the diff models tested
    results = results of the diff models
    """
    # Test options and evaluation metric
    num_folds = 10
    
    #num_folds =  k_folds
    scoring = 'r2'

    results = []
    names = []
    
    for name, model in models:
        kfold = StratifiedKFold(n_splits=num_folds)
        cv_results = cross_val_score(model, X_train,
                                     y_train, cv=kfold, scoring=scoring)
        results.append(cv_results.mean())
        names.append(name)
        msg = "%s: Accuracy = %f (std = %f)" % (name, 
                                                cv_results.mean(), 
                                                cv_results.std())
        print(msg)
    scoreDataFrame = pd.DataFrame({'Model':names, 'Score': results})
       
        
    return scoreDataFrame

# %%
models = Reg_getBasedModel()

# %%
Base_model = Reg_basedModels(X_train, y_train,models)
# Out:
# LinearR: Accuracy = 0.763472 (std = 0.056765)
# Ridge: Accuracy = 0.763474 (std = 0.056760)
# Lasso: Accuracy = 0.763472 (std = 0.056763)
# DT: Accuracy = 0.593155 (std = 0.108135)
# RF: Accuracy = 0.782264 (std = 0.066175)

# %%
Base_model
# Out:
#      Model     Score
# 0  LinearR  0.763472
# 1    Ridge  0.763474
# 2    Lasso  0.763472
# 3       DT  0.593155
# 4       RF  0.782264

# %% [markdown]
# ## Evaluate the models

# %%
def MetricsClas(models,X_train, y_train, X_test, y_test):
    for name, model in models:
        print('-*-'*25)
        print('Assessment of ', str(name), '\n')
        model_fit = model.fit(X_train, y_train)
        Allmetrics(model_fit, X_train, y_train, X_test, y_test)

# %%
models
# Out:
# [('LinearR', LinearRegression()),
#  ('Ridge', Ridge()),
#  ('Lasso', Lasso()),
#  ('DT', DecisionTreeRegressor()),
#  ('RF', RandomForestRegressor())]

# %%
def MetricsClas(models,X_train, y_train, X_test, y_test):
    for name, model in models:
        print('-*-'*25)
        print('Assessment of ', str(name), '\n')
        model_fit = model.fit(X_train, y_train)
        print(Allmetrics(model_fit, X_train, y_train, X_test, y_test))

# %%
models_comparison = MetricsClas(models,X_train, y_train, X_test, y_test)
# Out:
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  LinearR
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129504  20543.845838  8.093006e+08  28448.208346  0.778851  0.768
# Test   0.125109  21063.526331  8.755439e+08  29589.591230  0.801407    NaN
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  Ridge
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129503  20543.699963  8.093006e+08  28448.208511  0.778851  0.768
# Test   0.125109  21063.579915  8.755441e+08  29589.595133  0.801407    NaN
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  Lasso
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129504  20543.784886  8.093006e+08  28448.208375  0.778851  0.768
# ...

# %% [markdown]
# In general, these models show good performance metrics for the train dataset but not as good for the test. This could indicate overfitting.
#
# In order to improve the quality of the models, we attempted to scale the variables.

# %% [markdown]
# ## Scaling the variables

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler, RobustScaler

# We will define a function to apply any preprocessing method to the raw data

def Reg_GetScaledModel(nameOfScaler):
    """
    Function to define whether we want to apply any preprocessing method to the raw data.
    input:
    nameOfScale  = 'standard' (standardize),  'minmax' or 'robustscaler'
    """
    
    if nameOfScaler == 'standard':
        scaler = StandardScaler()
        
    elif nameOfScaler =='minmax':
        scaler = MinMaxScaler()
        
    elif nameOfScaler == 'robustscaler':
        scaler = RobustScaler()

    pipelines = []
    pipelines.append((nameOfScaler+'LinearR'  , 
                      Pipeline([('Scaler', scaler),
                                ('LinearR'   , LinearRegression())])))
    
    pipelines.append((nameOfScaler+'Ridge' , 
                      Pipeline([('Scaler', scaler),('Ridge', Ridge())])))
    
    pipelines.append((nameOfScaler+'Lasso', 
                      Pipeline([('Scaler', scaler),
                                ('Lasso'   , Lasso())])))
    
    pipelines.append((nameOfScaler+'DT' ,
                      Pipeline([('Scaler', scaler),
                                ('DT' , DecisionTreeRegressor())])))
    
    #pipelines.append((nameOfScaler+'SVM' ,
         #             Pipeline([('Scaler', scaler),
        #                        ('SVM-R' , SVR(kernel = 'rbf'))])))

    pipelines.append((nameOfScaler+'RF'  , 
                      Pipeline([('Scaler', scaler),
                                ('RF'  , RandomForestRegressor())])))
    return pipelines

# %%
def ScoreDataFrame(names,results):
    """
    A function to append the results of the different models
    assessed and put them together in a DF

    """
    def floatingDecimals(f_val, dec=3):
        prc = "{:."+str(dec)+"f}" 
    
        return float(prc.format(f_val))

    scores = []
    for r in results:
        scores.append(floatingDecimals(r.mean(),4))

    scoreDataFrame = pd.DataFrame({'Model':names, 'Score': scores})
    return scoreDataFrame

# %%
models = Reg_GetScaledModel('standard')
scaledScoreStandard = Reg_basedModels(X_train, y_train,models)
scaledScoreStandard
# Out:
# standardLinearR: Accuracy = 0.763472 (std = 0.056765)
# standardRidge: Accuracy = 0.763490 (std = 0.056734)
# standardLasso: Accuracy = 0.763471 (std = 0.056763)
# standardDT: Accuracy = 0.591029 (std = 0.132649)
# standardRF: Accuracy = 0.777567 (std = 0.070984)
#              Model     Score
# 0  standardLinearR  0.763472
# 1    standardRidge  0.763490
# 2    standardLasso  0.763471
# 3       standardDT  0.591029
# 4       standardRF  0.777567

# %%
MetricsClas(models,X_train, y_train, X_test, y_test)
# Out:
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  standardLinearR
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129504  20543.845838  8.093006e+08  28448.208346  0.778851  0.768
# Test   0.125109  21063.526331  8.755439e+08  29589.591230  0.801407    NaN
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  standardRidge
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129488  20542.373495  8.093021e+08  28448.234817  0.778851  0.768
# Test   0.125079  21062.551855  8.758227e+08  29594.302434  0.801344    NaN
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  standardLasso
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129503  20543.651033  8.093006e+08  28448.208400  0.778851  0.768
# ...

# %%
models = Reg_GetScaledModel('minmax')
scaledScoreMinmax = Reg_basedModels(X_train, y_train,models)
scaledScoreMinmax
# Out:
# minmaxLinearR: Accuracy = 0.763472 (std = 0.056765)
# minmaxRidge: Accuracy = 0.763357 (std = 0.056284)
# minmaxLasso: Accuracy = 0.763473 (std = 0.056750)
# minmaxDT: Accuracy = 0.614096 (std = 0.117969)
# minmaxRF: Accuracy = 0.778582 (std = 0.070718)
#            Model     Score
# 0  minmaxLinearR  0.763472
# 1    minmaxRidge  0.763357
# 2    minmaxLasso  0.763473
# 3       minmaxDT  0.614096
# 4       minmaxRF  0.778582

# %%
MetricsClas(models,X_train, y_train, X_test, y_test)
# Out:
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  minmaxLinearR
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129504  20543.845838  8.093006e+08  28448.208346  0.778851  0.768
# Test   0.125109  21063.526331  8.755439e+08  29589.591230  0.801407    NaN
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  minmaxRidge
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129303  20548.616114  8.110217e+08  28478.442503  0.778381  0.768
# Test   0.124529  21079.981328  8.859088e+08  29764.219587  0.799056    NaN
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  minmaxLasso
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129496  20542.931029  8.093006e+08  28448.209943  0.778851  0.768
# ...

# %%
models = Reg_GetScaledModel('robustscaler')
scaledScoreRobust = Reg_basedModels(X_train, y_train,models)
scaledScoreRobust
# Out:
# robustscalerLinearR: Accuracy = 0.763472 (std = 0.056765)
# robustscalerRidge: Accuracy = 0.763515 (std = 0.056687)
# robustscalerLasso: Accuracy = 0.763472 (std = 0.056760)
# robustscalerDT: Accuracy = 0.586350 (std = 0.121128)
# robustscalerRF: Accuracy = 0.776688 (std = 0.068959)
#                  Model     Score
# 0  robustscalerLinearR  0.763472
# 1    robustscalerRidge  0.763515
# 2    robustscalerLasso  0.763472
# 3       robustscalerDT  0.586350
# 4       robustscalerRF  0.776688

# %%
MetricsClas(models,X_train, y_train, X_test, y_test)
# Out:
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  robustscalerLinearR
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129504  20543.845838  8.093006e+08  28448.208346  0.778851  0.768
# Test   0.125109  21063.526331  8.755439e+08  29589.591230  0.801407    NaN
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  robustscalerRidge
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129468  20540.121776  8.093066e+08  28448.314243  0.778850  0.768
# Test   0.125038  21060.231097  8.760887e+08  29598.795742  0.801284    NaN
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  robustscalerLasso
#
#            MAPE           MAE           MSE          RMSE        R2  CV_R2
# Train  0.129502  20543.539986  8.093006e+08  28448.208505  0.778851  0.768
# ...

# %%
compareModels = pd.concat([Base_model,scaledScoreStandard, scaledScoreMinmax, scaledScoreRobust], axis=1)
compareModels
# Out:
#      Model     Score            Model     Score          Model     Score  \
# 0  LinearR  0.763472  standardLinearR  0.763472  minmaxLinearR  0.763472
# 1    Ridge  0.763474    standardRidge  0.763490    minmaxRidge  0.763357
# 2    Lasso  0.763472    standardLasso  0.763471    minmaxLasso  0.763473
# 3       DT  0.593155       standardDT  0.591029       minmaxDT  0.614096
# 4       RF  0.782264       standardRF  0.777567       minmaxRF  0.778582
#
#                  Model     Score
# 0  robustscalerLinearR  0.763472
# 1    robustscalerRidge  0.763515
# 2    robustscalerLasso  0.763472
# 3       robustscalerDT  0.586350
# 4       robustscalerRF  0.776688

# %% [markdown]
# The strategy to scale the data proved to be inefficient for the models tested. There is still indication of overfitting.
#
# The next strategy was to log transform the target variable.

# %% [markdown]
# ## Log Transform the target

# %%
df.head(2)
# Out:
#   Neighborhood  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  \
# 0      CollgCr            7       2003          2003       196.0          856
# 1      Veenker            3       1976          1976         3.0         1262
#
#    GrLivArea  GarageFinish  SalePrice
# 0       1710             1     208500
# 1       1262             1     181500

# %%
df['SalePrice'].describe()
# Out:
# count      1183.000000
# mean     172174.352494
# std       62358.037817
# min       39300.000000
# 25%      129900.000000
# 50%      159500.000000
# 75%      202950.000000
# max      451950.000000
# Name: SalePrice, dtype: float64

# %%
df['SalePrice_log'] = np.log(df['SalePrice'])
df.head(5)
# Out:
#   Neighborhood  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  \
# 0      CollgCr            7       2003          2003       196.0          856
# 1      Veenker            3       1976          1976         3.0         1262
# 2      CollgCr            7       2001          2002       162.0          920
# 4      NoRidge            8       2000          2000       350.0         1145
# 5      Mitchel            7       1993          1995         3.0          796
#
#    GrLivArea  GarageFinish  SalePrice  SalePrice_log
# 0       1710             1     208500      12.247694
# 1       1262             1     181500      12.109011
# 2       1786             1     223500      12.317167
# 4       2198             1     250000      12.429216
# 5       1362             0     143000      11.870600

# %%
f = plt.figure(figsize=(12,5))
ax = f.add_subplot(121)
sns.distplot(df['SalePrice'],color='green',ax=ax)
ax.set_title('Distribution of [SalePrice]')

ax=f.add_subplot(122)
sns.distplot(df['SalePrice_log'],color='red',ax=ax)
ax.set_title('Distribution of [SalePrice_log]');

# %%
X = df.drop(['SalePrice','SalePrice_log','Neighborhood'], axis=1)
y = df['SalePrice_log']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    random_state=42)

# %%
print('Shape of the raw data (X): {}'.format (X.shape))
print('Shape of the TARGET variable (y): {}'.format (y.shape))

print('\nShape of the Train data (X_train): {}'.format (X_train.shape))
print('Shape of the Train data (y_train): {}'.format (y_train.shape))

print('\nShape of the Test data (X_test): {}'.format (X_test.shape))
print('Shape of the TARGET Test data (y_test): {}'.format (y_test.shape))
# Out:
# Shape of the raw data (X): (1183, 7)
# Shape of the TARGET variable (y): (1183,)
#
# Shape of the Train data (X_train): (828, 7)
# Shape of the Train data (y_train): (828,)
#
# Shape of the Test data (X_test): (355, 7)
# Shape of the TARGET Test data (y_test): (355,)

# %% [markdown]
# Linear Regression:

# %%
linear = LinearRegression()
linear.fit(X_train,y_train)
Allmetrics(linear,X_train,y_train,X_test,y_test)
# Out:
#            MAPE       MAE       MSE      RMSE        R2  CV_R2
# Train  0.009801  0.116882  0.026166  0.161760  0.789693   0.78
# Test   0.009222  0.110526  0.020754  0.144063  0.835194    NaN

# %% [markdown]
# Linear Regression with Ridge Regularization:

# %%
ridge = Ridge()
ridge.fit(X_train,y_train)
Allmetrics(ridge,X_train,y_train,X_test,y_test)
# Out:
#            MAPE       MAE       MSE      RMSE        R2  CV_R2
# Train  0.009801  0.116881  0.026166  0.161760  0.789693   0.78
# Test   0.009222  0.110523  0.020753  0.144061  0.835200    NaN

# %% [markdown]
# Linear Regression with Lasso Regularization:

# %%
lasso = Lasso()
lasso.fit(X_train,y_train)
Allmetrics(lasso,X_train,y_train,X_test,y_test)
# Out:
#            MAPE       MAE       MSE      RMSE        R2  CV_R2
# Train  0.010541  0.125628  0.029709  0.172364  0.761216  0.754
# Test   0.009514  0.113985  0.022954  0.151504  0.817729    NaN

# %% [markdown]
# Decision Tree Regressor:

# %%
test3 = DecisionTreeRegressor()
test3.fit(X_train,y_train)
Allmetrics(test3,X_train,y_train,X_test,y_test)
# Out:
#            MAPE       MAE       MSE      RMSE        R2  CV_R2
# Train  0.000058  0.000676  0.000035  0.005900  0.999720  0.574
# Test   0.012346  0.147967  0.039493  0.198728  0.686395    NaN

# %% [markdown]
# Random Forest Regressor:

# %%
test4 = RandomForestRegressor()
test4.fit(X_train,y_train)
Allmetrics(test4,X_train,y_train,X_test,y_test)
# Out:
#            MAPE       MAE       MSE      RMSE        R2  CV_R2
# Train  0.003607  0.043013  0.003648  0.060396  0.970683   0.78
# Test   0.009005  0.107877  0.020277  0.142398  0.838983    NaN

# %% [markdown]
# It was not possible to improve the overfitting with the log transformation.
#
# The last strategy is build the Polynomial Model.

# %% [markdown]
# ## Linear Model with Polynomial Features

# %%
df = df.drop(['SalePrice_log'],axis=1)
df.head(2)
# Out:
#   Neighborhood  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  \
# 0      CollgCr            7       2003          2003       196.0          856
# 1      Veenker            3       1976          1976         3.0         1262
#
#    GrLivArea  GarageFinish  SalePrice
# 0       1710             1     208500
# 1       1262             1     181500

# %%
poly_reg = PolynomialFeatures(degree =2)

X_poly = poly_reg.fit_transform(X)
X_poly.shape
# Out:
# (1183, 36)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, 
                                                    test_size = 0.3, 
                                                    random_state = 42)

# %%
lin_reg_2 = LinearRegression()

lin_reg_2.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
accuracy = lin_reg_2.score(X_test, y_test)
print('Accuracy = '+ str(accuracy))
# Out:
# Accuracy = 0.8533468457081941

# %%
poly_res = Allmetrics(lin_reg_2,X_train, y_train, X_test, y_test)
poly_res
# Out:
#            MAPE       MAE       MSE      RMSE        R2  CV_R2
# Train  0.009070  0.108104  0.021497  0.146617  0.827225  0.767
# Test   0.008669  0.103563  0.018468  0.135898  0.853347    NaN

# %% [markdown]
# Although we can see overall lower accuracy metrics for the linear regression with the target variable polynomial target feature, the overall metrics show a better combined performance metric and the overfitting seemed to be regularized. This is our recommended model.

# %% [markdown]
# ___

# %% [markdown]
# # Model to predict Overall Quality of a house based on other features

# %%
df["OverallQual"].value_counts()
# Out:
# 7    593
# 3    442
# 8    114
# 9     25
# 0      5
# 2      4
# Name: OverallQual, dtype: int64

# %%
df["grade"] = np.where(df["OverallQual"] > 3, 1, 0)
df["grade"].value_counts()
# Out:
# 1    732
# 0    451
# Name: grade, dtype: int64

# %%
def metrics_train_Class(model, X_train, y_train):
    scoring = {'acc': 'accuracy',
           'prec_macro': 'precision_macro',
           'rec_macro': 'recall_macro',
           'f1_macro': 'f1_macro'}
    
    scores = cross_validate(model, X_train, y_train, cv=10, scoring=scoring)
    ypredTrain = model.predict(X_train)
    Acc_train = scores['test_acc'].mean()
    Precision_train = scores['test_prec_macro'].mean()
    Recall_train = scores['test_rec_macro'].mean()
    F1_train = scores['test_f1_macro'].mean()
    conf_matrix_train = confusion_matrix(y_train, ypredTrain)
    from sklearn.metrics import classification_report
    statist_train = []
   
    list_metrics = [Acc_train, Precision_train, Recall_train, F1_train]
    statist_train.append(list_metrics)
    statist_train = pd.DataFrame(statist_train,columns = ['Accuracy', 'Precision', 'Recall', 'f1'], index = ['Train'])
    
    print('-----------------------------------------')
    print('TRAIN results')
    print('-----------------------------------------')
    print('Confusion Matrix \n', conf_matrix_train)
    return statist_train


# In[ ]:


def metrics_test_Class(model, X_test, y_test):
    
    scoring = {'acc': 'accuracy',
           'prec_macro': 'precision_macro',
           'rec_macro': 'recall_macro',
           'f1_macro': 'f1_macro'}
    
    scores = cross_validate(model, X_test, y_test, cv=10, scoring=scoring)
    ypredtest = model.predict(X_test)
    report = classification_report(y_test, ypredtest,zero_division=0, output_dict=True)
    report = pd.DataFrame(report).T
    
    Acc_test = report.loc['accuracy', :].mean()  
    Rest_metrics = report.iloc[:-3,:]
    
    Precision_test = Rest_metrics.loc[:,'precision'].mean()
    Recall_test = Rest_metrics.loc[:,'recall'].mean()
    F1_test = Rest_metrics.loc[:,'f1-score'].mean()
    conf_matrix_test = confusion_matrix(y_test, ypredtest)
    
    statist_test = []
   
    list_metrics = [Acc_test, Precision_test, Recall_test, F1_test]
    statist_test.append(list_metrics)
    statist_test = pd.DataFrame(statist_test,columns = ['Accuracy', 'Precision', 'Recall', 'f1'], index = ['test'])
     
    print('-----------------------------------------')
    print('TEST results')
    print('-----------------------------------------')
    print('Confusion Matrix \n', conf_matrix_test)
    print(' Classification report \n', Rest_metrics)
    return statist_test


# In[ ]:


def AllmetricsClass(model,X_train,y_train,X_test,y_test):
    
    stats_train = metrics_train_Class(model, X_train,y_train)
    stats_test = metrics_test_Class(model, X_test,y_test)
    final_metrics = pd.concat([stats_train,stats_test])
    print()
    print('++++++++ Summary of the Metrics +++++++++++++++++++++++++++++++++++')
    print(final_metrics)
    return final_metrics

# %%
X = df.drop(['OverallQual','Neighborhood','grade'], axis=1)
y = df['grade']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
print('Shape of the raw data (X): {}'.format (X.shape))
print('Shape of the TARGET variable (y): {}'.format (y.shape))

print('\nShape of the Train data (X_train): {}'.format (X_train.shape))
print('Shape of the Train data (y_train): {}'.format (y_train.shape))

print('\nShape of the Test data (X_test): {}'.format (X_test.shape))
print('Shape of the TARGET Test data (y_test): {}'.format (y_test.shape))
# Out:
# Shape of the raw data (X): (1183, 7)
# Shape of the TARGET variable (y): (1183,)
#
# Shape of the Train data (X_train): (792, 7)
# Shape of the Train data (y_train): (792,)
#
# Shape of the Test data (X_test): (391, 7)
# Shape of the TARGET Test data (y_test): (391,)

# %% [markdown]
# ## Random Forest

# %%
rand_forest = RandomForestClassifier(n_estimators=200)
rand_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
y_pred_RF = rand_forest.predict(X_test)

print(classification_report(y_test, y_pred_RF))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.59      0.60       143
#            1       0.77      0.77      0.77       248
#
#     accuracy                           0.71       391
#    macro avg       0.69      0.68      0.68       391
# weighted avg       0.71      0.71      0.71       391

# %%
AllmetricsClass(rand_forest,X_train,y_train,X_test,y_test)
# Out:
# -----------------------------------------
# TRAIN results
# -----------------------------------------
# Confusion Matrix
#  [[308   0]
#  [  0 484]]
# -----------------------------------------
# TEST results
# -----------------------------------------
# Confusion Matrix
#  [[ 85  58]
#  [ 56 192]]
#  Classification report
#     precision    recall  f1-score  support
# 0   0.602837  0.594406  0.598592    143.0
# 1   0.768000  0.774194  0.771084    248.0
#
# ++++++++ Summary of the Metrics +++++++++++++++++++++++++++++++++++
#        Accuracy  Precision    Recall        f1
# Train  0.632706   0.607578  0.601477  0.602044
# test   0.708440   0.685418  0.684300  0.684838
#        Accuracy  Precision    Recall        f1
# Train  0.632706   0.607578  0.601477  0.602044
# test   0.708440   0.685418  0.684300  0.684838

# %% [markdown]
# ## Decision Tree

# %%
X = df.drop(['OverallQual','Neighborhood','grade'], axis=1)
y = df['grade']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
tree = DecisionTreeClassifier(random_state=42)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
AllmetricsClass(tree,X_train,y_train,X_test,y_test)
# Out:
# -----------------------------------------
# TRAIN results
# -----------------------------------------
# Confusion Matrix
#  [[308   0]
#  [  0 484]]
# -----------------------------------------
# TEST results
# -----------------------------------------
# Confusion Matrix
#  [[ 79  64]
#  [ 71 177]]
#  Classification report
#     precision    recall  f1-score  support
# 0   0.526667  0.552448  0.539249    143.0
# 1   0.734440  0.713710  0.723926    248.0
#
# ++++++++ Summary of the Metrics +++++++++++++++++++++++++++++++++++
#        Accuracy  Precision    Recall        f1
# Train  0.626297   0.610294  0.612799  0.610728
# test   0.654731   0.630553  0.633079  0.631588
#        Accuracy  Precision    Recall        f1
# Train  0.626297   0.610294  0.612799  0.610728
# test   0.654731   0.630553  0.633079  0.631588

# %% [markdown]
# # Model to predict High Price of a house based on other features

# %%
df.head(2)
# Out:
#   Neighborhood  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  \
# 0      CollgCr            7       2003          2003       196.0          856
# 1      Veenker            3       1976          1976         3.0         1262
#
#    GrLivArea  GarageFinish  SalePrice  grade
# 0       1710             1     208500      1
# 1       1262             1     181500      0

# %%
df['SalePrice'].describe()
# Out:
# count      1183.000000
# mean     172174.352494
# std       62358.037817
# min       39300.000000
# 25%      129900.000000
# 50%      159500.000000
# 75%      202950.000000
# max      451950.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# We consider as a High Price categorical, the house which are up the 3Q.

# %%
df[df['SalePrice']>=202950]
# Out:
#      Neighborhood  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0         CollgCr            7       2003          2003       196.0
# 2         CollgCr            7       2001          2002       162.0
# 4         NoRidge            8       2000          2000       350.0
# 6         Somerst            8       2004          2005       186.0
# 22        CollgCr            8       2002          2002       281.0
# ...           ...          ...        ...           ...         ...
# 1426      NoRidge            7       1994          1994       448.0
# 1442      Somerst            0       2008          2008       160.0
# 1447      CollgCr            8       1995          1996       438.0
# 1456       NWAmes            3       1978          1988       119.0
# 1457      Crawfor            7       1941          2006         3.0
#
#       TotalBsmtSF  GrLivArea  GarageFinish  SalePrice  grade
# 0             856       1710             1     208500      1
# ...

# %%
df["price"] = np.where(df["SalePrice"] > 202950, 1, 0)
df["price"].value_counts()
# Out:
# 0    887
# 1    296
# Name: price, dtype: int64

# %% [markdown]
# ## Build the models

# %%
X = df.drop(['Neighborhood', 'SalePrice','grade','price'], axis=1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    random_state=42)

# %%
def GetBasedModel():
    basedModels = []
    basedModels.append(('LR'   , LogisticRegression()))
    basedModels.append(('KNN'  , KNeighborsClassifier()))
    basedModels.append(('CART' , DecisionTreeClassifier()))
    basedModels.append(('SVM'  , SVC()))
    basedModels.append(('RF'   , RandomForestClassifier()))
    return basedModels

# %%
def BasedModels(X_train, y_train,models):

    # Test options and evaluation metric
    num_folds = 10
    
    #num_folds =  k_folds
    scoring = 'roc_auc'

    results = []
    names = []
    
    for name, model in models:
        kfold = StratifiedKFold(n_splits=num_folds)
        cv_results = cross_val_score(model, X_train,
                                     y_train, cv=kfold, scoring=scoring)
        results.append(cv_results)
        names.append(name)
        msg = "%s: AUC = %f (std = %f)" % (name, 
                                                cv_results.mean(), 
                                                cv_results.std())
        print(msg)
        
    return names, results

# %%
models = GetBasedModel()
names,results = BasedModels(X_train, y_train,models)
# Out:
# LR: AUC = 0.928169 (std = 0.027647)
# KNN: AUC = 0.917742 (std = 0.037539)
# CART: AUC = 0.830240 (std = 0.041171)
# SVM: AUC = 0.926400 (std = 0.028855)
# RF: AUC = 0.962170 (std = 0.018464)

# %%
Base_model = ScoreDataFrame(names,results)
Base_model
# Out:
#   Model   Score
# 0    LR  0.9282
# 1   KNN  0.9177
# 2  CART  0.8302
# 3   SVM  0.9264
# 4    RF  0.9622

# %%
def MetricsClas(models,X_train, y_train, X_test, y_test):
    for name, model in models:
        print('-*-'*25)
        print('Assessment of ', str(name), '\n')
        model_fit = model.fit(X_train, y_train)
        print(AllmetricsClass(model_fit, X_train, y_train, X_test, y_test))

# %%
MetricsClas(models,X_train, y_train, X_test, y_test)
# Out:
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# Assessment of  LR
#
# -----------------------------------------
# TRAIN results
# -----------------------------------------
# Confusion Matrix
#  [[576  41]
#  [ 67 144]]
# -----------------------------------------
# TEST results
# -----------------------------------------
# Confusion Matrix
#  [[255  15]
#  [ 15  70]]
#  Classification report
#     precision    recall  f1-score  support
# 0   0.944444  0.944444  0.944444    270.0
# 1   0.823529  0.823529  0.823529     85.0
#
# ++++++++ Summary of the Metrics +++++++++++++++++++++++++++++++++++
#        Accuracy  Precision    Recall        f1
# Train  0.865912   0.836927  0.807329  0.817637
# test   0.915493   0.883987  0.883987  0.883987
#        Accuracy  Precision    Recall        f1
# Train  0.865912   0.836927  0.807329  0.817637
# test   0.915493   0.883987  0.883987  0.883987
# ...

# %% [markdown]
# ### Random Forest Results

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train,y_train)
y_pred = rf_model.predict(X_test)

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot = True)
# Out:
# <AxesSubplot:>

# %%
rf_model = AllmetricsClass(rf_model,X_train,y_train,X_test,y_test)
# Out:
# -----------------------------------------
# TRAIN results
# -----------------------------------------
# Confusion Matrix
#  [[617   0]
#  [  0 211]]
# -----------------------------------------
# TEST results
# -----------------------------------------
# Confusion Matrix
#  [[260  10]
#  [ 15  70]]
#  Classification report
#     precision    recall  f1-score  support
# 0   0.945455  0.962963  0.954128    270.0
# 1   0.875000  0.823529  0.848485     85.0
#
# ++++++++ Summary of the Metrics +++++++++++++++++++++++++++++++++++
#        Accuracy  Precision    Recall        f1
# Train  0.909506   0.896134  0.862962  0.874758
# test   0.929577   0.910227  0.893246  0.901307

# %% [markdown]
# # **Final Conclusion and Recommendations**

# %% [markdown]
# ## **What is the best neighborhood to invest and with the highest potential for valuation over time?**
#
# ---
#
# To help John to decide on what is the best neighborhood to invest, we added the feature "Price per Square Feet" in our dataset. This metric is calculated dividing the total price by the GrLivArea and it give us a relative measure of value to compare the neighborhoods.

# %%
df["dolar_per_sqf"] = df["SalePrice"]/df["GrLivArea"]

# %%
df.head(3)
# Out:
#   Neighborhood  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  TotalBsmtSF  \
# 0      CollgCr            7       2003          2003       196.0          856
# 1      Veenker            3       1976          1976         3.0         1262
# 2      CollgCr            7       2001          2002       162.0          920
#
#    GrLivArea  GarageFinish  SalePrice  grade  price  dolar_per_sqf
# 0       1710             1     208500      1      1     121.929825
# 1       1262             1     181500      0      0     143.819334
# 2       1786             1     223500      1      1     125.139978

# %%
neigh_price_mean = df.groupby(["Neighborhood"])["dolar_per_sqf"].agg(['mean', 'count']).reset_index().round(2)
neigh_price_mean.sort_values(by="mean", ascending=False, inplace=True)
neigh_price_mean
# Out:
#    Neighborhood    mean  count
# 24      Veenker  154.98     11
# 16      NridgHt  154.31     43
# 22      StoneBr  151.96     15
# 23       Timber  139.31     28
# 5       CollgCr  136.58    129
# 21      Somerst  135.08     49
# 0       Blmngtn  131.56     12
# 4       ClearCr  130.56     23
# 11      Mitchel  128.87     42
# 15      NoRidge  128.76     32
# 20      SawyerW  122.03     49
# 19       Sawyer  119.28     67
# 6       Crawfor  119.19     42
# 12        NAmes  117.21    198
# 8       Gilbert  116.92     64
# 13      NPkVill  114.95      8
# 14       NWAmes  112.44     63
# 3       BrkSide  106.28     54
# 7       Edwards  102.48     82
# 10      MeadowV   99.17     16
# 1       Blueste   98.97      2
# 2        BrDale   95.25     12
# 9        IDOTRR   94.64     29
# 17      OldTown   92.80     92
# 18        SWISU   86.90     21

# %% [markdown]
# By grouping the houses into neighborhood and calculating the average price per square feet, we can see that the most expensive neighborhood is the Venkeer, whilst the one with the cheapest houses on average is the SWISU.
# We could also see that there are more houses available to buy in NAmes, followed by CollgCr, which might indicate a unbalanced market with higher supply than demand, a red flag for future prices expectations.

# %%
px.bar(neigh_price_mean, x="Neighborhood", y="mean", text="count")
# Out:
# <div>                            <div id="0bed148a-04a1-42c2-b955-b04d5d0de52e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bed148a-04a1-42c2-b955-b04d5d0de52e")) {                    Plotly.newPlot(                        "0bed148a-04a1-42c2-b955-b04d5d0de52e",                        [{"alignmentgroup": "True", "hovertemplate": "Neighborhood=%{x}<br>mean=%{y}<br>count=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text": [11.0, 43.0, 15.0, 28.0, 129.0, 49.0, 12.0, 23.0, 42.0, 32.0, 49.0, 67.0, 42.0, 198.0, 64.0, 8.0, 63.0, 54.0, 82.0, 16.0, 2.0, 12.0, 29.0, 92.0, 21.0], "textposition": "auto", "type": "bar", "x": ["Veenker", "NridgHt", "StoneB
# ...

# %% [markdown]
# In order to define the best neighboorhood to invest, we added to our new dataset the mean for overall quality. Using a scatterplot we were able to see that the NoRidge and Timber are neighborhoods with the best quality and price relationship and also with a reasonable quantity of houses available to buy.

# %%
neigh_qual_mean = df.groupby(["Neighborhood"])["OverallQual"].agg(['mean']).reset_index().round(2)
neigh_qual_mean.sort_values(by="mean", ascending=False, inplace=True)
neigh_mean = pd.merge(neigh_price_mean, neigh_qual_mean, how="left", on=["Neighborhood"]).rename(columns={"mean_x": "mean_price", "mean_y": "mean_quality"})

# %%
neigh_mean
# Out:
#    Neighborhood  mean_price  count  mean_quality
# 0       Veenker      154.98     11          6.00
# 1       NridgHt      154.31     43          7.26
# 2       StoneBr      151.96     15          7.93
# 3        Timber      139.31     28          6.96
# 4       CollgCr      136.58    129          6.49
# 5       Somerst      135.08     49          6.63
# 6       Blmngtn      131.56     12          7.17
# 7       ClearCr      130.56     23          4.74
# 8       Mitchel      128.87     42          5.12
# 9       NoRidge      128.76     32          7.69
# 10      SawyerW      122.03     49          5.18
# 11       Sawyer      119.28     67          5.93
# 12      Crawfor      119.19     42          5.55
# 13        NAmes      117.21    198          5.27
# 14      Gilbert      116.92     64          5.30
# 15      NPkVill      114.95      8          3.00
# 16       NWAmes      112.44     63          5.00
# 17      BrkSide      106.28     54          4.67
# ...

# %%
fig = px.scatter(neigh_mean, x="mean_price", y="mean_quality", size="count", color=str("Neighborhood"))
fig.update_layout(width=900,height=500)
fig.show()
# Out:
# <div>                            <div id="000b85f3-67fe-4bab-ae88-35474a501c88" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("000b85f3-67fe-4bab-ae88-35474a501c88")) {                    Plotly.newPlot(                        "000b85f3-67fe-4bab-ae88-35474a501c88",                        [{"hovertemplate": "Neighborhood=Veenker<br>mean_price=%{x}<br>mean_quality=%{y}<br>count=%{marker.size}<extra></extra>", "legendgroup": "Veenker", "marker": {"color": "#636efa", "size": [11], "sizemode": "area", "sizeref": 0.495, "symbol": "circle"}, "mode": "markers", "name": "Veenker", "orientation": "v", "showlegend": true, "type": "scatter", "x": [154.98], "xaxis": "x", "y": [6.0], "yaxis": "y"}, {"hovertemplate": "Neighborhood=NridgHt<br>mean_price=%{x}<br>
# ...

# %% [markdown]
# ## **Once we identify the best neighborhood, should he consider buying an older house and renovating before selling to maximize his profit?**
#
# ---
#
# By narrowing down our dataset to these two neighborhood, we can see that newest houses with a higher quality are better priced. We can also see that there are some houses available in these neighborhood that have moderate quality but good prices. Therefore, a good option would be buying an older house (approximately 20 years old) and remodelling to improve quality and sell it with a higher price.

# %%
noridge = df[df['Neighborhood'].isin(['NoRidge', 'Timber'])]
noridge = noridge.groupby(["Neighborhood","YearBuilt","OverallQual"])["dolar_per_sqf"].agg(['mean']).reset_index().round(2)
noridge
# Out:
#    Neighborhood  YearBuilt  OverallQual    mean
# 0       NoRidge       1990            8  107.47
# 1       NoRidge       1991            8  107.57
# 2       NoRidge       1992            7  107.79
# 3       NoRidge       1992            8   99.23
# 4       NoRidge       1993            7  119.64
# 5       NoRidge       1994            7  130.73
# 6       NoRidge       1994            8  143.21
# 7       NoRidge       1995            8  141.49
# 8       NoRidge       1996            7  132.54
# 9       NoRidge       1997            8  145.48
# 10      NoRidge       1998            7  120.17
# 11      NoRidge       1998            8  133.18
# 12      NoRidge       1999            8  135.12
# 13      NoRidge       1999            9  128.19
# 14      NoRidge       2000            8  111.14
# 15       Timber       1948            7   94.84
# 16       Timber       1959            7  128.01
# 17       Timber       1963            7  118.77
# 18       Timber       1965            7  156.19
# ...

# %%
fig = px.scatter(noridge, x="YearBuilt", y="mean", color=str("OverallQual"))
fig.update_layout(width=900,height=500)
fig.show()
# Out:
# <div>                            <div id="6a0e2298-4c26-46da-91bf-211e06a1ad35" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a0e2298-4c26-46da-91bf-211e06a1ad35")) {                    Plotly.newPlot(                        "6a0e2298-4c26-46da-91bf-211e06a1ad35",                        [{"hovertemplate": "YearBuilt=%{x}<br>mean=%{y}<br>OverallQual=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [8, 8, 7, 8, 7, 7, 8, 8, 7, 8, 7, 8, 8, 9, 8, 7, 7, 7, 7, 8, 3, 3, 3, 7, 7, 3, 8, 7, 8, 7, 8, 8, 7, 8, 9, 8, 9, 9], "coloraxis": "coloraxis", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [1990, 1991, 1992, 1992, 1993, 1994, 1994, 1995, 1996, 1997, 1998, 1998, 
# ...

# %% [markdown]
# ## **What are the ideal house features to look for when deciding on investment?**
#
# ---
#
# The initial dataset has 81 features. After the initial data clean-up, in order to build a model to predict sales price of a house, we narrowed down our independent variables to only 7 using Random Forest Regressor to determine their importance.
# The model indicated that the following variables are more relevant to predict the sales price for the houses:
#
# - GrLivArea: Above grade (ground) living area square feet
# - OverallQual: Rates the overall material and finish of the house
# - TotalBsmtSF: Total square feet of basement area
# - YearBuilt: Original construction date
# - GarageFinish: Interior finish of the garage
# - GarageType: Garage location
# - BsmtExposure: Refers to walkout or garden level walls

# %%
feat_imp = pd.DataFrame(import_dict, columns=["feature", "importance"]).sort_values(by="importance", ascending=False)
feat_imp.importance = 100.0 * (feat_imp.importance / feat_imp.importance.max())
feat_imp = feat_imp[feat_imp.importance > threshold]
px.bar(feat_imp, x="feature", y="importance")
# Out:
# <div>                            <div id="7d96226c-ca05-4876-9650-dcbd03479dc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d96226c-ca05-4876-9650-dcbd03479dc1")) {                    Plotly.newPlot(                        "7d96226c-ca05-4876-9650-dcbd03479dc1",                        [{"alignmentgroup": "True", "hovertemplate": "feature=%{x}<br>importance=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["GrLivArea", "OverallQual", "TotalBsmtSF", "YearBuilt", "YearRemodAdd", "GarageFinish", "MasVnrArea"], "xaxis": "x", "y": [100.0, 52.781080628474854, 26.740796240974152, 18.87852161057994, 10.3523303810152
# ...

# %% [markdown]
# ## **What is the best model to predict house sales price considering the data available?**
#
# ---
#
# As mentioned above, we narrowed down our model to 7 features that presented the highest importance rates to predict Sales Price for the houses in Ames, IA. Using this set of independent variables (X) and the SalesPrice as dependent variable (y), we evaluated 5 different models:
#
# - Linear Regression
# - Ridge
# - Lasso
# - Decision Tree
# - Random Forest Regressor
#
# Among these model, the Random Forest Regressor showed the best accuracy, however the test set showed performance metrics significantly lower than the training set, which indicates a potential over fitting.
# We have also tried scaling the variables and the target, but it did not yield any improvements in performance.
#
# In parallel, we tried to build models based on linear regression to determine the variables with the highest coefficients. This also showed poor results, which reinforced our conclusion that the dataset is not linear.
#
# In face of the unsatisfactory results, we used a linear regression with polynomial features, as this approach provides a simple way to provide a non-linear fit to data.
#
# This scenario scored slightly lower in the cross validation, however the other performance metrics as a whole showed better results.
#
# Our recommendation to John is to use linear regression with polynomial features.

# %%
Base_model
# Out:
#   Model   Score
# 0    LR  0.9282
# 1   KNN  0.9177
# 2  CART  0.8302
# 3   SVM  0.9264
# 4    RF  0.9622

# %%
poly_res
# Out:
#            MAPE       MAE       MSE      RMSE        R2  CV_R2
# Train  0.009070  0.108104  0.021497  0.146617  0.827225  0.767
# Test   0.008669  0.103563  0.018468  0.135898  0.853347    NaN

# %% [markdown]
# ## **Can we predict the quality of a house, using the same set of features?**
#
# ---

# %% [markdown]
# At first, we used OverallQual as the target feature and classified the values into two major groups: houses with poor to below average quality (0) and houses above average quality (1). For the independent features, we considered the same set of features on top of the SalePrice. This exercise did not yield satisfactory results. In order to improve this model to predict OverallQual, the recommendation is to make a new selection of features with greater importance and rebuild the model.
#
# For now, to keep the same set of features, our strategy has been the construction of Classification Model considering the same set of independent variables (X) and the Price as dependent variable (y). The discrete value as result is High Price of a house, considering the ones with a price above of the 3º quartile. We evaluated 5 different models:
#
# - Logistic Regression
# - K Neighbors
# - Decision Tree
# - SVM
# - Random Forest
#
# Most models showed a similar satisfactory results, but the Randon Forest performed better, with better accuracy metrics. With this model, John will be able to tell if the house would be priced at a higher range based on its specifications.

# %%
rf_model
# Out:
#        Accuracy  Precision    Recall        f1
# Train  0.909506   0.896134  0.862962  0.874758
# test   0.929577   0.910227  0.893246  0.901307
